# %% [markdown]
# # DenseNet121 Baseline No Fourier — FIXED Test Evaluation
#
# Javított baseline test-evaluation notebook.
#
# Fontos javítás:
# - a modell classifier része pontosan ugyanaz, mint a tanításnál,
# - checkpoint local `/content` alá másolva töltődik be,
# - `strict=True`, hogy ne adjon hamis eredményt részleges betöltéssel.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image
from tqdm.auto import tqdm

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from torchvision import models, transforms
from torchvision.transforms import InterpolationMode

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
print("Torch:", torch.__version__)
# Out:
# Device: cpu
# Torch: 2.10.0+cpu

# %%
# =========================
# PATHOK ÉS BEÁLLÍTÁSOK
# =========================

DENSENET_CKPT = "/content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/best_densenet121_baseline.pth"

TEST_DIR = "/content/drive/MyDrive/Brain MRI/dataset/Test"

OUT_DIR = "/content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED"
os.makedirs(OUT_DIR, exist_ok=True)

IMG_SIZE = 224
BATCH_SIZE = 8
NUM_WORKERS = 2

CLASS_NAMES = ["glioma", "meningioma", "no_tumor", "pituitary"]
label_map = {c: i for i, c in enumerate(CLASS_NAMES)}
label_map_inv = {i: c for c, i in label_map.items()}

IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

print("Checkpoint exists:", os.path.exists(DENSENET_CKPT))
print("Test exists:", os.path.exists(TEST_DIR))
print("Output:", OUT_DIR)

if not os.path.exists(DENSENET_CKPT):
    raise FileNotFoundError(DENSENET_CKPT)

if not os.path.exists(TEST_DIR):
    raise FileNotFoundError(TEST_DIR)
# Out:
# Checkpoint exists: True
# Test exists: True
# Output: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED

# %%
# =========================
# TEST FÁJLOK BEOLVASÁSA
# =========================

def normalize_folder_name(name):
    s = name.lower().strip().replace("-", "_").replace(" ", "_")
    if "glioma" in s:
        return "glioma"
    if "meningioma" in s:
        return "meningioma"
    if "pituitary" in s:
        return "pituitary"
    if s in ["no_tumor", "notumor", "no_tumour", "notumour", "normal", "healthy"]:
        return "no_tumor"
    if "no" in s and ("tumor" in s or "tumour" in s):
        return "no_tumor"
    return s

valid_exts = (".png", ".jpg", ".jpeg", ".bmp", ".webp", ".tif", ".tiff")

rows = []

print("Test mappa tartalma:")
for folder in sorted(os.listdir(TEST_DIR)):
    folder_path = os.path.join(TEST_DIR, folder)
    if not os.path.isdir(folder_path):
        continue

    label = normalize_folder_name(folder)

    n_imgs = len([f for f in os.listdir(folder_path) if f.lower().endswith(valid_exts)])
    print(f"{folder:25s} -> {label:12s} -> {n_imgs} kép")

    if label not in label_map:
        print("Kihagyva:", folder)
        continue

    for fname in sorted(os.listdir(folder_path)):
        if fname.lower().endswith(valid_exts):
            rows.append({
                "image_path": os.path.join(folder_path, fname),
                "folder_label": folder,
                "label": label,
                "label_idx": label_map[label]
            })

df_test = pd.DataFrame(rows)

if len(df_test) == 0:
    raise RuntimeError("Nem találtam képeket a test mappában.")

print("\nÖsszes test kép:", len(df_test))
display(df_test["label"].value_counts().reindex(CLASS_NAMES).fillna(0).astype(int).to_frame("count"))

file_list_path = os.path.join(OUT_DIR, "test_file_list.csv")
df_test.to_csv(file_list_path, index=False)
print("Mentve:", file_list_path)
# Out:
# Test mappa tartalma:
# glioma                    -> glioma       -> 603 kép
# meningioma                -> meningioma   -> 436 kép
# notumor                   -> no_tumor     -> 389 kép
# pituitary                 -> pituitary    -> 429 kép
#
# Összes test kép: 1857
#             count
# label
# glioma        603
# meningioma    436
# no_tumor      389
# pituitary     429
# Mentve: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/test_file_list.csv

# %%
# =========================
# DATASET ÉS DATALOADER
# =========================

test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE), interpolation=InterpolationMode.BILINEAR),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD)
])

class BrainTumorDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.data = dataframe.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        image = Image.open(row["image_path"]).convert("RGB")
        label = int(row["label_idx"])

        if self.transform:
            image = self.transform(image)

        return image, label, row["image_path"]

test_dataset = BrainTumorDataset(df_test, transform=test_transform)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=torch.cuda.is_available()
)

print("Dataset:", len(test_dataset))
print("Batches:", len(test_loader))
# Out:
# Dataset: 1857
# Batches: 233

# %%
# =========================
# MODELL: DenseNet121 baseline - JAVÍTOTT
# Pontosan mint a tanításnál:
# model.classifier = Sequential(Dropout(0.25), Linear(...))
# =========================

model = models.densenet121(weights=None)
in_features = model.classifier.in_features
model.classifier = nn.Sequential(
    nn.Dropout(0.25),
    nn.Linear(in_features, len(CLASS_NAMES))
)
model = model.to(device)

print(model.classifier)
# Out:
# Sequential(
#   (0): Dropout(p=0.25, inplace=False)
#   (1): Linear(in_features=1024, out_features=4, bias=True)
# )

# %%
# =========================
# CHECKPOINT BETÖLTÉS - JAVÍTOTT
# =========================
# Drive hiba ellen először local /content alá másoljuk.
# strict=True: ha nem pontos az architektúra, azonnal hibát dob.

LOCAL_CKPT = "/content/best_densenet121_baseline.pth"
shutil.copy2(DENSENET_CKPT, LOCAL_CKPT)

try:
    ckpt = torch.load(LOCAL_CKPT, map_location=device, weights_only=True)
except TypeError:
    ckpt = torch.load(LOCAL_CKPT, map_location=device)
except Exception:
    ckpt = torch.load(LOCAL_CKPT, map_location=device)

if isinstance(ckpt, dict) and "model_state_dict" in ckpt:
    state = ckpt["model_state_dict"]
elif isinstance(ckpt, dict) and "state_dict" in ckpt:
    state = ckpt["state_dict"]
else:
    state = ckpt

state = {k.replace("module.", ""): v for k, v in state.items()}

model.load_state_dict(state, strict=True)
model = model.to(device)
model.eval()

print("Checkpoint sikeresen betöltve strict=True módban.")
print("Local checkpoint:", LOCAL_CKPT)
# Out:
# Checkpoint sikeresen betöltve strict=True módban.
# Local checkpoint: /content/best_densenet121_baseline.pth

# %%
# =========================
# TEST KIÉRTÉKELÉS
# =========================

y_true = []
y_pred = []
y_prob = []
paths = []

use_amp = torch.cuda.is_available()

with torch.no_grad():
    for images, labels, image_paths in tqdm(test_loader, desc="Testing"):
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        with torch.amp.autocast("cuda", enabled=use_amp):
            outputs = model(images)

        probs = torch.softmax(outputs, dim=1)
        preds = torch.argmax(probs, dim=1)

        y_true.extend(labels.cpu().numpy().tolist())
        y_pred.extend(preds.cpu().numpy().tolist())
        y_prob.extend(probs.cpu().numpy().tolist())
        paths.extend(list(image_paths))

y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_prob = np.array(y_prob)

print("Predikciók elkészültek.")
print("y_true:", y_true.shape)
print("y_pred:", y_pred.shape)
print("y_prob:", y_prob.shape)
# Out:
# Testing:   0%|          | 0/233 [00:00<?, ?it/s]
# Predikciók elkészültek.
# y_true: (1857,)
# y_pred: (1857,)
# y_prob: (1857, 4)

# %%
# =========================
# SUMMARY METRICS
# =========================

acc = accuracy_score(y_true, y_pred)

summary_df = pd.DataFrame([{
    "Model": "DenseNet121 Baseline No Fourier",
    "Test Accuracy": acc,
    "Macro Precision": precision_score(y_true, y_pred, average="macro", zero_division=0),
    "Macro Recall": recall_score(y_true, y_pred, average="macro", zero_division=0),
    "Macro F1-score": f1_score(y_true, y_pred, average="macro", zero_division=0),
    "Weighted Precision": precision_score(y_true, y_pred, average="weighted", zero_division=0),
    "Weighted Recall": recall_score(y_true, y_pred, average="weighted", zero_division=0),
    "Weighted F1-score": f1_score(y_true, y_pred, average="weighted", zero_division=0),
    "Number of test images": len(y_true)
}])

display(summary_df)

summary_path = os.path.join(OUT_DIR, "test_summary_metrics.csv")
summary_df.to_csv(summary_path, index=False)
print("Mentve:", summary_path)
# Out:
#                              Model  Test Accuracy  Macro Precision  \
# 0  DenseNet121 Baseline No Fourier       0.942919         0.944996
#
#    Macro Recall  Macro F1-score  Weighted Precision  Weighted Recall  \
# 0      0.944258        0.944521            0.943121         0.942919
#
#    Weighted F1-score  Number of test images
# 0           0.942926                   1857
# Mentve: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/test_summary_metrics.csv

# %%
# =========================
# CLASSIFICATION REPORT
# =========================

report_df = pd.DataFrame(
    classification_report(
        y_true,
        y_pred,
        labels=list(range(len(CLASS_NAMES))),
        target_names=CLASS_NAMES,
        output_dict=True,
        zero_division=0
    )
).transpose()

display(report_df)

report_path = os.path.join(OUT_DIR, "classification_report.csv")
report_df.to_csv(report_path)
print("Mentve:", report_path)
# Out:
#               precision    recall  f1-score      support
# glioma         0.930116  0.927032  0.928571   603.000000
# meningioma     0.903587  0.924312  0.913832   436.000000
# no_tumor       0.960106  0.928021  0.943791   389.000000
# pituitary      0.986175  0.997669  0.991889   429.000000
# accuracy       0.942919  0.942919  0.942919     0.942919
# macro avg      0.944996  0.944258  0.944521  1857.000000
# weighted avg   0.943121  0.942919  0.942926  1857.000000
# Mentve: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/classification_report.csv

# %%
# =========================
# PAPER-READY METRIKA TÁBLÁZAT
# =========================

prec, rec, f1, support = precision_recall_fscore_support(
    y_true,
    y_pred,
    labels=list(range(len(CLASS_NAMES))),
    zero_division=0
)

rows = []

for i, cls in enumerate(CLASS_NAMES):
    rows.append({
        "Model": "DenseNet121 Baseline No Fourier",
        "Class": cls,
        "Precision": round(float(prec[i]), 4),
        "Recall": round(float(rec[i]), 4),
        "F1-Score": round(float(f1[i]), 4),
        "Support": int(support[i]),
        "Accuracy": ""
    })

rows.append({
    "Model": "",
    "Class": "Macro Avg",
    "Precision": round(float(precision_score(y_true, y_pred, average="macro", zero_division=0)), 4),
    "Recall": round(float(recall_score(y_true, y_pred, average="macro", zero_division=0)), 4),
    "F1-Score": round(float(f1_score(y_true, y_pred, average="macro", zero_division=0)), 4),
    "Support": int(np.sum(support)),
    "Accuracy": ""
})

rows.append({
    "Model": "",
    "Class": "Weighted Avg",
    "Precision": round(float(precision_score(y_true, y_pred, average="weighted", zero_division=0)), 4),
    "Recall": round(float(recall_score(y_true, y_pred, average="weighted", zero_division=0)), 4),
    "F1-Score": round(float(f1_score(y_true, y_pred, average="weighted", zero_division=0)), 4),
    "Support": int(np.sum(support)),
    "Accuracy": round(float(acc), 4)
})

results_table_df = pd.DataFrame(rows)
display(results_table_df)

results_path = os.path.join(OUT_DIR, "test_results_table.csv")
results_table_df.to_csv(results_path, index=False)
print("Mentve:", results_path)
# Out:
#                              Model         Class  Precision  Recall  F1-Score  \
# 0  DenseNet121 Baseline No Fourier        glioma     0.9301  0.9270    0.9286
# 1  DenseNet121 Baseline No Fourier    meningioma     0.9036  0.9243    0.9138
# 2  DenseNet121 Baseline No Fourier      no_tumor     0.9601  0.9280    0.9438
# 3  DenseNet121 Baseline No Fourier     pituitary     0.9862  0.9977    0.9919
# 4                                      Macro Avg     0.9450  0.9443    0.9445
# 5                                   Weighted Avg     0.9431  0.9429    0.9429
#
#    Support Accuracy
# 0      603
# 1      436
# 2      389
# 3      429
# 4     1857
# 5     1857   0.9429
# Mentve: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/test_results_table.csv

# %%
# =========================
# CONFUSION MATRIX
# =========================

cm = confusion_matrix(y_true, y_pred, labels=list(range(len(CLASS_NAMES))))

cm_df = pd.DataFrame(
    cm,
    index=[f"True: {c}" for c in CLASS_NAMES],
    columns=[f"Pred: {c}" for c in CLASS_NAMES]
)

display(cm_df)

cm_csv = os.path.join(OUT_DIR, "confusion_matrix_counts.csv")
cm_df.to_csv(cm_csv)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues", cbar=True)
plt.title("Confusion Matrix")
plt.ylabel("True label")
plt.xlabel("Predicted label")
plt.xticks(rotation=35, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

cm_png = os.path.join(OUT_DIR, "confusion_matrix.png")
plt.savefig(cm_png, dpi=300, bbox_inches="tight")
plt.show()

print("CSV:", cm_csv)
print("PNG:", cm_png)
# Out:
#                   Pred: glioma  Pred: meningioma  Pred: no_tumor  \
# True: glioma               559                30              11
# True: meningioma            26               403               4
# True: no_tumor              16                12             361
# True: pituitary              0                 1               0
#
#                   Pred: pituitary
# True: glioma                    3
# True: meningioma                3
# True: no_tumor                  0
# True: pituitary               428
# CSV: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/confusion_matrix_counts.csv
# PNG: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/confusion_matrix.png

# %%
# =========================
# NORMALIZED CONFUSION MATRIX
# =========================

row_sums = cm.sum(axis=1, keepdims=True)
cm_norm = np.divide(cm, row_sums, out=np.zeros_like(cm, dtype=float), where=row_sums != 0)

cm_norm_df = pd.DataFrame(
    cm_norm,
    index=[f"True: {c}" for c in CLASS_NAMES],
    columns=[f"Pred: {c}" for c in CLASS_NAMES]
)

display(cm_norm_df)

cm_norm_csv = os.path.join(OUT_DIR, "confusion_matrix_normalized.csv")
cm_norm_df.to_csv(cm_norm_csv)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_norm_df, annot=True, fmt=".2f", cmap="Blues", cbar=True, vmin=0, vmax=1)
plt.title("Normalized Confusion Matrix")
plt.ylabel("True label")
plt.xlabel("Predicted label")
plt.xticks(rotation=35, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

cm_norm_png = os.path.join(OUT_DIR, "normalized_confusion_matrix.png")
plt.savefig(cm_norm_png, dpi=300, bbox_inches="tight")
plt.show()

print("CSV:", cm_norm_csv)
print("PNG:", cm_norm_png)
# Out:
#                   Pred: glioma  Pred: meningioma  Pred: no_tumor  \
# True: glioma          0.927032          0.049751        0.018242
# True: meningioma      0.059633          0.924312        0.009174
# True: no_tumor        0.041131          0.030848        0.928021
# True: pituitary       0.000000          0.002331        0.000000
#
#                   Pred: pituitary
# True: glioma             0.004975
# True: meningioma         0.006881
# True: no_tumor           0.000000
# True: pituitary          0.997669
# CSV: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/confusion_matrix_normalized.csv
# PNG: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/normalized_confusion_matrix.png

# %%
# =========================
# PER-IMAGE PREDICTIONS + MISCLASSIFIED
# =========================

pred_rows = []

for i in range(len(y_true)):
    row = {
        "image_path": paths[i],
        "true_idx": int(y_true[i]),
        "pred_idx": int(y_pred[i]),
        "true_label": label_map_inv[int(y_true[i])],
        "predicted_label": label_map_inv[int(y_pred[i])],
        "correct": bool(y_true[i] == y_pred[i]),
        "confidence": float(np.max(y_prob[i]))
    }

    for j, cname in enumerate(CLASS_NAMES):
        row[f"prob_{cname}"] = float(y_prob[i][j])

    pred_rows.append(row)

pred_df = pd.DataFrame(pred_rows)
display(pred_df.head(20))

pred_path = os.path.join(OUT_DIR, "per_image_predictions.csv")
pred_df.to_csv(pred_path, index=False)
print("Mentve:", pred_path)

wrong_df = pred_df[pred_df["correct"] == False].copy()
wrong_df = wrong_df.sort_values("confidence", ascending=False)

display(wrong_df.head(50))

wrong_path = os.path.join(OUT_DIR, "misclassified.csv")
wrong_df.to_csv(wrong_path, index=False)
print("Mentve:", wrong_path)
# Out:
#                                            image_path  true_idx  pred_idx  \
# 0   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 1   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 2   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 3   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 4   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 5   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 6   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 7   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 8   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 9   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 10  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 11  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 12  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 13  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 14  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 15  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 16  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 17  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 18  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
# 19  /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         0
#
#    true_label predicted_label  correct  confidence  prob_glioma  \
# 0      glioma          glioma     True    0.999327     0.999327
# 1      glioma          glioma     True    0.999973     0.999973
# 2      glioma          glioma     True    0.999928     0.999928
# 3      glioma          glioma     True    0.999968     0.999968
# 4      glioma          glioma     True    0.999830     0.999830
# 5      glioma          glioma     True    0.999278     0.999278
# 6      glioma          glioma     True    0.999931     0.999931
# 7      glioma          glioma     True    0.999970     0.999970
# 8      glioma          glioma     True    0.932183     0.932183
# 9      glioma          glioma     True    0.999659     0.999659
# 10     glioma          glioma     True    0.998221     0.998221
# 11     glioma          glioma     True    0.999736     0.999736
# 12     glioma          glioma     True    0.999788     0.999788
# 13     glioma          glioma     True    0.999570     0.999570
# 14     glioma          glioma     True    0.999739     0.999739
# 15     glioma          glioma     True    0.998358     0.998358
# 16     glioma          glioma     True    0.999953     0.999953
# 17     glioma          glioma     True    0.999971     0.999971
# 18     glioma          glioma     True    0.999588     0.999588
# 19     glioma          glioma     True    0.999981     0.999981
#
#     prob_meningioma  prob_no_tumor  prob_pituitary
# 0          0.000643   1.076323e-06        0.000028
# 1          0.000006   7.804936e-07        0.000020
# 2          0.000025   1.115815e-07        0.000048
# 3          0.000025   1.738061e-06        0.000005
# 4          0.000026   4.360207e-07        0.000143
# 5          0.000119   9.528107e-08        0.000603
# 6          0.000023   3.127029e-07        0.000046
# 7          0.000024   3.271505e-06        0.000003
# 8          0.001334   5.586057e-02        0.010623
# 9          0.000017   2.035461e-06        0.000322
# 10         0.001665   9.707770e-05        0.000017
# 11         0.000153   7.229210e-07        0.000110
# 12         0.000056   6.362585e-07        0.000156
# 13         0.000067   4.735292e-08        0.000362
# 14         0.000128   1.028234e-07        0.000133
# 15         0.000283   5.510175e-07        0.001359
# 16         0.000011   2.125120e-08        0.000036
# 17         0.000017   1.818525e-06        0.000010
# 18         0.000089   3.381676e-07        0.000323
# 19         0.000015   5.550040e-07        0.000004
# Mentve: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/per_image_predictions.csv
#                                              image_path  true_idx  pred_idx  \
# 487   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 485   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 486   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 490   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 488   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 1355  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         1
# 1230  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         1
# 522   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 1373  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         1
# 519   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 1075  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         1
# 520   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 514   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 527   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 518   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 190   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 388   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 559   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 389   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 524   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 1095  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         1
# 419   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 558   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 213   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 523   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 980   /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 418   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 820   /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 390   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 557   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 1315  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         1
# 827   /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 555   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 160   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 799   /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 525   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 1291  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         1
# 521   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 768   /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 421   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 987   /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 748   /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 561   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         2
# 1263  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         0
# 529   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 1025  /content/drive/MyDrive/Brain MRI/dataset/Test/...         1         0
# 526   /content/drive/MyDrive/Brain MRI/dataset/Test/...         0         1
# 1337  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         0
# 1214  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         0
# 1266  /content/drive/MyDrive/Brain MRI/dataset/Test/...         2         0
#
#       true_label predicted_label  correct  confidence   prob_glioma  \
# 487       glioma      meningioma    False    0.999978  1.330217e-05
# 485       glioma      meningioma    False    0.999929  3.201554e-05
# 486       glioma      meningioma    False    0.999924  5.478827e-05
# 490       glioma      meningioma    False    0.999784  1.276734e-04
# 488       glioma      meningioma    False    0.999735  2.025778e-04
# 1355    no_tumor      meningioma    False    0.999652  1.540888e-04
# 1230    no_tumor      meningioma    False    0.999588  1.972777e-04
# 522       glioma      meningioma    False    0.999472  1.379902e-04
# 1373    no_tumor      meningioma    False    0.999453  8.588787e-07
# 519       glioma      meningioma    False    0.999326  3.039305e-05
# 1075    no_tumor      meningioma    False    0.999215  1.169601e-07
# 520       glioma      meningioma    False    0.997971  2.378477e-04
# 514       glioma      meningioma    False    0.997919  1.872287e-03
# 527       glioma      meningioma    False    0.997757  1.496041e-03
# 518       glioma      meningioma    False    0.997690  5.967456e-04
# 190       glioma      meningioma    False    0.996554  3.424530e-03
# 388       glioma      meningioma    False    0.996554  3.425780e-03
# 559       glioma        no_tumor    False    0.996299  2.690802e-05
# 389       glioma      meningioma    False    0.995938  3.884117e-03
# 524       glioma      meningioma    False    0.995141  3.792844e-03
# 1095    no_tumor      meningioma    False    0.994642  3.042938e-03
# 419       glioma        no_tumor    False    0.994267  4.950746e-03
# 558       glioma        no_tumor    False    0.994144  2.530766e-04
# 213       glioma      meningioma    False    0.992672  5.681358e-03
# 523       glioma      meningioma    False    0.992263  6.697639e-05
# 980   meningioma          glioma    False    0.990633  9.906325e-01
# 418       glioma        no_tumor    False    0.989758  9.019221e-03
# 820   meningioma          glioma    False    0.988226  9.882256e-01
# 390       glioma      meningioma    False    0.987462  1.212960e-02
# 557       glioma        no_tumor    False    0.985989  1.935367e-04
# 1315    no_tumor      meningioma    False    0.985769  2.643306e-05
# 827   meningioma          glioma    False    0.984596  9.845963e-01
# 555       glioma        no_tumor    False    0.984093  6.101252e-05
# 160       glioma      meningioma    False    0.983562  1.626244e-02
# 799   meningioma          glioma    False    0.980706  9.807057e-01
# 525       glioma      meningioma    False    0.979207  1.758854e-02
# 1291    no_tumor      meningioma    False    0.977069  1.467497e-03
# 521       glioma      meningioma    False    0.971692  2.653952e-02
# 768   meningioma          glioma    False    0.971412  9.714125e-01
# 421       glioma        no_tumor    False    0.970725  2.662565e-02
# 987   meningioma          glioma    False    0.964790  9.647897e-01
# 748   meningioma          glioma    False    0.961098  9.610982e-01
# 561       glioma        no_tumor    False    0.954007  1.129340e-04
# 1263    no_tumor          glioma    False    0.949158  9.491578e-01
# 529       glioma      meningioma    False    0.941816  6.955999e-03
# 1025  meningioma          glioma    False    0.933102  9.331025e-01
# 526       glioma      meningioma    False    0.930522  6.807995e-02
# 1337    no_tumor          glioma    False    0.928806  9.288061e-01
# 1214    no_tumor          glioma    False    0.921303  9.213030e-01
# 1266    no_tumor          glioma    False    0.915339  9.153389e-01
#
#       prob_meningioma  prob_no_tumor  prob_pituitary
# 487          0.999978   4.719044e-06    3.611769e-06
# 485          0.999929   3.152513e-05    7.228659e-06
# 486          0.999924   1.697296e-05    4.285861e-06
# 490          0.999784   7.632319e-05    1.166035e-05
# 488          0.999735   5.956590e-05    2.392705e-06
# 1355         0.999652   5.770772e-05    1.363195e-04
# 1230         0.999588   5.412434e-05    1.607226e-04
# 522          0.999472   2.315328e-04    1.589790e-04
# 1373         0.999453   2.644268e-05    5.201204e-04
# 519          0.999326   3.061603e-05    6.130146e-04
# 1075         0.999215   4.449359e-05    7.398070e-04
# 520          0.997971   1.393624e-03    3.980982e-04
# 514          0.997919   4.282316e-06    2.044935e-04
# 527          0.997757   1.198738e-04    6.268562e-04
# 518          0.997690   8.199956e-04    8.931826e-04
# 190          0.996554   4.916794e-06    1.633127e-05
# 388          0.996554   4.493360e-06    1.582456e-05
# 559          0.003665   9.962992e-01    8.503901e-06
# 389          0.995938   1.732276e-04    4.868906e-06
# 524          0.995141   2.597698e-05    1.040538e-03
# 1095         0.994642   2.315126e-03    1.152243e-08
# 419          0.000778   9.942673e-01    3.603476e-06
# 558          0.005596   9.941444e-01    6.241594e-06
# 213          0.992672   2.125908e-05    1.625310e-03
# 523          0.992263   1.538179e-03    6.132167e-03
# 980          0.001551   8.293167e-04    6.986974e-03
# 418          0.001218   9.897584e-01    4.000013e-06
# 820          0.007611   1.185849e-03    2.978114e-03
# 390          0.987462   3.591993e-04    4.897877e-05
# 557          0.013216   9.859891e-01    6.012782e-04
# 1315         0.985769   1.103762e-02    3.166950e-03
# 827          0.010387   2.403583e-03    2.613537e-03
# 555          0.015806   9.840930e-01    4.030059e-05
# 160          0.983562   3.030989e-06    1.723478e-04
# 799          0.000311   1.843483e-02    5.484421e-04
# 525          0.979207   1.283848e-03    1.920957e-03
# 1291         0.977069   1.373219e-02    7.731612e-03
# 521          0.971692   4.294120e-05    1.725627e-03
# 768          0.008455   3.704594e-03    1.642795e-02
# 421          0.002625   9.707245e-01    2.495510e-05
# 987          0.004876   3.004875e-03    2.732919e-02
# 748          0.036069   2.223056e-03    6.095770e-04
# 561          0.045839   9.540067e-01    4.152630e-05
# 1263         0.000857   4.995096e-02    3.375919e-05
# 529          0.941816   4.605397e-02    5.174387e-03
# 1025         0.037351   1.534586e-07    2.954626e-02
# 526          0.930522   3.019982e-04    1.095947e-03
# 1337         0.002224   6.847095e-02    4.987521e-04
# 1214         0.001921   7.672530e-02    5.106692e-05
# 1266         0.060183   2.402267e-02    4.554892e-04
# Mentve: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/misclassified.csv

# %%
# =========================
# MISCLASSIFIED EXAMPLES
# =========================

def show_misclassified_examples(wrong_df, max_images=12):
    if len(wrong_df) == 0:
        print("Nincs hibás klasszifikáció.")
        return

    sample_df = wrong_df.head(max_images)
    n = len(sample_df)
    cols = 4
    rows = int(np.ceil(n / cols))

    plt.figure(figsize=(4 * cols, 4 * rows))

    for i, (_, row) in enumerate(sample_df.iterrows()):
        img = Image.open(row["image_path"]).convert("RGB")
        plt.subplot(rows, cols, i + 1)
        plt.imshow(img)
        plt.axis("off")
        plt.title(
            f"True: {row['true_label']}\nPred: {row['predicted_label']}\nConf: {row['confidence']:.2f}",
            fontsize=10
        )

    plt.tight_layout()
    out_path = os.path.join(OUT_DIR, "misclassified_examples.png")
    plt.savefig(out_path, dpi=300, bbox_inches="tight")
    plt.show()
    print("Mentve:", out_path)

show_misclassified_examples(wrong_df)
# Out:
# Mentve: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED/misclassified_examples.png

# %%
print("Kész.")
print("Eredmények:", OUT_DIR)
print("\nFájlok:")
for f in sorted(os.listdir(OUT_DIR)):
    print("-", f)
# Out:
# Kész.
# Eredmények: /content/drive/MyDrive/Brain MRI/FNO_clas/no fourier/densenet121_test_evaluation_FIXED
#
# Fájlok:
# - classification_report.csv
# - confusion_matrix.png
# - confusion_matrix_counts.csv
# - confusion_matrix_normalized.csv
# - misclassified.csv
# - misclassified_examples.png
# - normalized_confusion_matrix.png
# - per_image_predictions.csv
# - test_file_list.csv
# - test_results_table.csv
# - test_summary_metrics.csv
